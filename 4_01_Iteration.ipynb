# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardoughton/spatial_computing/blob/main/4_01_Iteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔁 🤖 **Week 4.1 — Iteration** 🔁 🤖
#
# Iteration refers to the use of loops in computer programming.
#
# By "iteration", we are referring to the repeated use of a process in a systematic way. So we could define a set of processing instructions for our data, and then via iteration, we could use a Python loop to feed each row in our dataset one-by-one through these steps. Sometimes we might specify that we want the iteration process to continue until a pre-defined condition is met (at which point the loop ceases).
#
# There are multiple different types of loops that we will cover here, including `for` loops, `while` loops etc. Additionally, time will be spent covering some basic looping logic e.g., `continue`, `break` etc.

# %% [markdown]
# ### 🗓️ **Our week 4 adventure**
#
# This week we will cover [1. Iteration](4_01_Iteration.ipynb) and [2. Shapely](4_02_Intro_To_Shapely.ipynb).
#
# As usual, we will work through the various examples I provide and I want you to try predict what will happen. Then you can have a go at each **Task** in the code cell underneath.
#
# Run the examples from top to bottom to try gain situational awareness, but I would like you to at least read the code and try predict what you think will happen before looking at the real answer (as failure boost learning, when followed with the right answer, so it's good to make mistakes/get things wrong).
#
# Our tasks build on the methods introduced just above them.

# %% [markdown]
# ## 🧭 **Iteration - For Loop**
#
# We have already used these types of iterative structures briefly in the class, e.g., for looping over some form of data structure in Python.
#
# This data structure could be a range, string, list, tuple, dictionary etc.
#
# * When we begin with the term `for`, Python knows we want to start a `for` loop (see that this is indicated by `for` being a protected word in Python, because it is a different color).
# * We then specify our iterator. Python allows this to be user-defined (e.g., `i`).
# * Next, we need to specify that this iterator will be iterating `in` the following object.
# * Finally, we specify the data structure or function we want to iterate with.
#
# To iterate over a range of numbers, we use the built-in function `range()`.

# %%
# Example: Iterating over a range
for i in range(1,5):
  print(i)                     # Please note this line is indented

# %% [markdown]
# The `range()` function will also allow you to increment your iterator.
#
# The function follows this pattern `range(start, stop, step=1)`, as follows.

# %%
# Example: Iterating over a range via an increment
for i in range(1,10,2):
  print(i)

# %% [markdown]
# We can also iterate over a list sequence, each element at a time.

# %%
# Example: Iterating over a list
my_list = [1,2,3,4]
for i in my_list:
  print(i)

# %% [markdown]
# Or we could iterate over a tuple, if we desire.

# %%
# Example: Iterating over a tuple
my_tuple = (1,2,3,4)
for i in my_tuple:
  print(i)

# %% [markdown]
# However, to iterate over a **dictionary** as key-value pairs, we use `.items()`.
#
# Here we unpack each pair into two loop variables, `key` and `value`. We still process one pair at a time.

# %%
# Example: Iterating over a dict key-value pairs
my_dict = {
    'a': 1,
    'b': 2,
    'c': 3,
    'd': 4
}
for key, value in my_dict.items():
  print(key, value)

# %% [markdown]
# If you like, you could just print the keys, using the `.keys()` function.

# %%
# Example: Iterating over dict keys
my_dict = {
    'a': 1,
    'b': 2,
    'c': 3,
    'd': 4
}
for key in my_dict.keys():
  print(key)

# %% [markdown]
# And equally, you could do the same just for the values, using the `.values()` function.

# %%
# Example: Iterating over dict values
my_dict = {
    'a': 1,
    'b': 2,
    'c': 3,
    'd': 4
}
for key in my_dict.values():
  print(key)

# %% [markdown]
# It is also possible to iterate over a string, if we want to, iterating over one character at a time (although we will use this less frequently, than the iteration approach for lists and dicts).

# %%
# Example: Iterating over a string
my_string ='abcde'
for i in my_string:
  print(i)

# %% [markdown]
# Finally, we might want to iterate over a data structure and also use an index at the same time, via the `enumerate()` function. So the first element, at index position zero, will be present here with the value of 0 (and so on, and so forth).

# %%
# Example: Iterating over a list with an index
my_list = [1,2,3,4]
for index, i in enumerate(my_list):
  print("My index value is : {}".format(index))
  print("My iterator value is : {}".format(i))
  print('')

# %%
# Example: Iterating over a list with an index (but with f-strings)
my_list = [1,2,3,4]
for index, i in enumerate(my_list):
  print(f"My index value is : {index}")
  print(f"My iterator value is : {i}")
  print('')

# %% [markdown]
# ### **Task 1 — 🤖 Robot picnic countdown**
#
# Our picnic robot is labeling baskets. Print all numbers from 5 to 12 (inclusive) using a `for` loop. Then start at 5 and count in steps of 3, stopping before 13. Predict both outputs before running your code. Hint: the stop value in `range()` is excluded.

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 2 — 🦆 A duck’s very busy week**
#
# Create a list containing the seven weekday names. Use a `for` loop to print a cheerful duck adventure for each day, such as “Monday: pond patrol!” **Bonus:** use `enumerate()` to number the days from 1.

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 3 — 👽 Meet your mapping mascot**
#
# Invent a friendly alien surveyor. Store its name, age and birth month/year in a tuple, then print each element using a `for` loop. Fictional details are encouraged : ]

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 4 — 🍦 Ice cream headquarters**
#
# Create a dictionary describing an imaginary ice cream shop, with keys for its name, town and coordinate tuple. Use `.items()` to print each key and value. Keep these fictional coordinates separate from real-world mapping data.

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 5 — 🐿️ Acorn accounting**
#
# A squirrel finds `[1, 2, 3, 4]` acorns at four park stops. Start a total at zero, then use a `for` loop to add each count and print the running total. Your final total should be 10. Give the squirrel a congratulatory message!

# %%
# Enter your attempt here

# %% [markdown]
# ## 🧭 **Iteration - While loop**
#
# A `while` loop repeats **while its condition is True**. It stops when that condition becomes False.
#
# Remember to update the variable used by your condition inside the loop, otherwise you may create a loop that never stops!

# %%
# Example: Iterating via a while loop
quantity = 0
while quantity < 3:
    print("Quantity is currently {}".format(quantity))
    quantity += 1

# %% [markdown]
# In the example below, we will import the `random` package (which should come shipped with a base Python installation).
#
# * We will then create an empty list, which we will add desired values to.
# * After generating a random value between zero and 1, we append any value below 0.3 to our list, via the `append()` function.
# * Finally, each time we loop, we check the length of the list. The `while` loop will cease once we have 3 values in the list (thus, `len(my_list) < 3`).

# %%
# Example: Generating a list of random numbers with a specific length
import random

my_list = []

while len(my_list) < 3:
    print("Length of my_list is currently: {}".format(len(my_list)))
    random_number = random.random()
    print("Random number is: {}".format(random_number))
    if random_number < 0.3:
      my_list.append(random_number)

# %% [markdown]
# ### **Task 6 — 🚀 Tiny rocket launch**
#
# Create a `while` loop that prints launch checks numbered 0 through 4. Increase your counter inside the loop. Once the loop ends, print “Ready for the picnic!”

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 7 — 🧊 Penguin ice cubes**
#
# A penguin needs cubes with side lengths 4, 6, 8, …, 20 meters. Use a `while` loop to print each side length and its cubed value (volume in cubic meters). Start at 4 and increase by 2 each time. Your last volume should be 8000.

# %%
# Enter your attempt here

# %% [markdown]
# ## 🧭 **Iteration - Loop control**
#
# We have a few options to help us control a loop, including using `continue`, `break`, etc.
#
# *   `continue` indicates that if some condition is met, the loop should skip to the next iteration.
# *   `break` indicates that if some condition is met, we want to stop iterating.
#
# In the example below, we can see that when our iterator `i` matches either 1 or 3 (thus, matches our condition `if i == 1` or `if i == 3`), the loop continues to the next number without printing.

# %%
# Example: Loop control via continue
my_list = [1,2,3,4]
for i in my_list:
  if i == 1:
    continue
  if i == 3:
    continue
  print(i)

# %% [markdown]
# Whereas, in the example below the loop breaks once the condition is met (e.g., the condition being `i == 3`), and thus does not continue looping to print beyond 3.

# %%
# Example: Loop control via break
my_list = [1,2,3,4]
for i in my_list:
  print(i)
  if i == 3:
    break

# %% [markdown]
# ### **Task 8 — 🍄 Mushroom stepping stones**
#
# Use a `for` loop over numbers 1 through 5. Use `continue` to skip even-numbered stones. Predict the three numbers your code will print.

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 9 — 🐉 Let sleeping dragons nap**
#
# Visit caves numbered 1 through 10, but use `break` when the cave number equals 4. Put the check before your print statement, so only caves 1, 2 and 3 are printed. Explain what changes if you print before checking.

# %%
# Enter your attempt here

# %% [markdown]
# ### **Task 10 — 🎈 Balloon delivery**
#
# Create a list containing numbers 1 through 6. Loop through it and print only the even numbers: these are the houses waiting for balloons. Add a cheerful delivery message for each house.

# %%
# Enter your attempt here

# %% [markdown]
# ### 🎯 **Task — 🧺 Plan a robot picnic route**
#
# * Loop through the stops and print each name with its coordinates.
# * Use `continue` to skip the closed stop.
# * Count the stops visited and print a celebration at the end. You should visit 3 stops.
# * **Bonus:** stop after visiting the picnic meadow using `break`. Where should the counter update go?

# %%
picnic_stops = [
    {"name": "Cupcake kiosk", "xy": (0, 0), "open": True},
    {"name": "Sleepy dragon bridge", "xy": (2, 1), "open": False},
    {"name": "Duck pond", "xy": (3, 4), "open": True},
    {"name": "Picnic meadow", "xy": (6, 4), "open": True},
]

# Enter your attempt here

# %% [markdown]
# ### 🎉 **Before you go…**
#
# Have a go at explaining one new technique to a neighbor. Show them a result you predicted correctly and one thing that surprised you. Add a text cell with your explanation, then save your notebook.
